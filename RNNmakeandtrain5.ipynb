# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/AIProj/Dataset/stock_details_5_years.csv")

df
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company
# 0        43.083508  167080000       0.00           0.0    AAPL
# 1       104.636131   28123200       0.00           0.0    MSFT
# 2        54.729000   31004000       0.00           0.0   GOOGL
# 3        83.678497  132264000       0.00           0.0    AMZN
# 4        39.037853   54917200       0.04           0.0    NVDA
# ...            ...        ...        ...           ...     ...
# 602957   26.150000    1729147       0.00           0.0     PPL
# 602958   28.350000    1940066       0.00           0.0    FITB
# 602959   75.610001     298699       0.00           0.0     IFF
# 602960   44.209999    2217579       0.00           0.0     CCJ
# 602961   83.889999     830092       0.00           0.0     LYV
#
# [602962 rows x 9 columns]

# %%
# no need to run this
max_value = df['Close'].max()
min_value = df['Close'].min()

print(f"Maximum value: {max_value}, Minimum value: {min_value}")
# Out:
# Maximum value: 6509.35009765625, Minimum value: 1.03488409519196

# %%
datestrings = df['Date']

# Remove timezone information
datestrings = datestrings.apply(lambda x: x.split('-')[0])

# Convert date strings to Unix timestamps (seconds since the epoch)
unix_timestamps = pd.to_datetime(datestrings).apply(lambda x: x.timestamp())

# Convert Unix timestamps to floats
date_ints = unix_timestamps.astype(int)

# Replace the original date column with the float values
df['Date_ints'] = date_ints

# Reset the index of data
df.reset_index(drop=True, inplace=True)

# %%
df

# %%
# Normalizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1, 1))

# %%
type(data)
# Out:
# numpy.ndarray

# %%
# Create sequences and labels
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        label = data[i + seq_length]
        sequences.append(seq)
        labels.append(label)

    # Convert the list of sequences and labels to a single NumPy array
    sequences = np.array(sequences)
    labels = np.array(labels)

    return torch.tensor(sequences), torch.tensor(labels)

seq_length = 10
X, y = create_sequences(scaled_data, seq_length)

# %%
# ignore for now

def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length - 1, 'Date_ints'].values
        label = data[i + seq_length, 'Close']
        sequences.append(seq)
        labels.append(label)

# Convert the list of sequences and labels to a single NumPy array
    sequences = np.array(sequences)
    labels = np.array(labels)

    return torch.tensor(sequences), torch.tensor(labels)

seq_length = 10
X, y = create_sequences(data, seq_length)

# %%
# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hx=None):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out

# Define hyperparameters
input_size = 1
hidden_size = 100
num_layers = 3
output_size = 1
num_epochs = 100
learning_rate = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Create the model
model = RNN(input_size, hidden_size, num_layers, output_size).to(device)

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Free up GPU memory
# (Resolved?)
torch.cuda.empty_cache()

PYTORCH_CUDA_ALLOC_CONF=0.5

# %%
# Train the model
for epoch in range(num_epochs):
    model.train()
    outputs = model(X_train.float().to(device))
    loss = criterion(outputs, y_train.float().to(device))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 5 == 0:
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item()}')
# Out:
# Epoch [5/100], Loss: 0.8597584366798401
# Epoch [10/100], Loss: 0.8511343002319336
# Epoch [15/100], Loss: 0.8454227447509766
# Epoch [20/100], Loss: 0.8432894349098206
# Epoch [25/100], Loss: 0.8429824709892273
# Epoch [30/100], Loss: 0.8412080407142639
# Epoch [35/100], Loss: 0.8395564556121826
# Epoch [40/100], Loss: 0.8380711078643799
# Epoch [45/100], Loss: 0.835728108882904
# Epoch [50/100], Loss: 0.8326269388198853
# Epoch [55/100], Loss: 0.8288779258728027
# Epoch [60/100], Loss: 0.8239613175392151
# Epoch [65/100], Loss: 0.8165515661239624
# Epoch [70/100], Loss: 0.8051486611366272
# Epoch [75/100], Loss: 0.7910171747207642
# Epoch [80/100], Loss: 0.7781903147697449
# Epoch [85/100], Loss: 0.7608463764190674
# Epoch [90/100], Loss: 0.7404759526252747
# Epoch [95/100], Loss: 0.7200472354888916
# Epoch [100/100], Loss: 0.6974985003471375

# %%
# Define the local path for saving the model
local_path = input("/content/drive/MyDrive/AIProj/Models")

# Save the trained model
torch.save(model.state_dict(), local_path)
# Out:
# /content/drive/MyDrive/AIProj/Models/rnn4

# %% [markdown]
# Evaluation

# %%
#ignore

# Select the top 4 companies
top_companies = ['AAPL', 'MSFT', 'AMZN', 'GOOGL']
df_top = df[df['Company'].isin(top_companies)].copy()

# Preprocess the data
df = df.set_index('Date_ints')
df = df.sort_index()

# Use the 'close' column as the target variable
data = df[['Close']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d5bc1bcc1296> in <cell line: 6>()
#       4
#       5 # Preprocess the data
# ----> 6 df = df.set_index('Date_ints')
#       7 df = df.sort_index()
#       8
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['Date_ints'] are in the columns"

# %%
# Define a function to get predictions for a given company
def get_predictions(company_name, model, scaler):
    # Filter data for the given company
    company_data = df[df['Company'] == company_name]['Close'].values.reshape(-1, 1)
    company_data = scaler.transform(company_data).reshape(1, -1, 1)

    # Convert to PyTorch tensor and move to device
    company_data = torch.tensor(company_data, dtype=torch.float32).to(device)

    # Get initial hidden state
    batch_size = 1
    h0 = torch.zeros(1, batch_size, hidden_size).to(device)

    # Get predictions
    with torch.no_grad():
        prediction = model(company_data, h0)

    # Inverse transform predictions
    prediction = scaler.inverse_transform(prediction.cpu().numpy()).reshape(-1)

    return prediction

# Get predictions for the top 4 companies
top_companies = ['AAPL', 'MSFT', 'GOOGL', 'AMZN']
predictions = {}
for company in top_companies:
    prediction = get_predictions(company, model, scaler)
    predictions[company] = prediction

# Display predictions
for company, prediction in predictions.items():
    print(f"Predicted closing price for {company}: {prediction[-1]}")
# Out:
# Predicted closing price for AAPL: 116.3813247680664
# Predicted closing price for MSFT: 409.63818359375
# Predicted closing price for GOOGL: 72.87936401367188
# Predicted closing price for AMZN: 81.9839859008789

# %%
# Define a function to get predictions for a given company
def get_predictions(company_name, model, scaler):
    # Filter data for the given company
    company_data = df[df['Company'] == company_name]['Close'].values.reshape(-1, 1)
    company_data = scaler.transform(company_data).reshape(1, -1, 1)

    # Convert to PyTorch tensor and move to device
    company_data = torch.tensor(company_data, dtype=torch.float32).to(device)

    # Get initial hidden state
    batch_size = 1
    h0 = torch.zeros(1, batch_size, hidden_size).to(device)

    # Get predictions
    with torch.no_grad():
        prediction = model(company_data, h0)

    # Inverse transform predictions
    prediction = scaler.inverse_transform(prediction.cpu().numpy()).reshape(-1)

    return prediction

# Get predictions for the top 4 companies
top_companies = ['AAPL', 'MSFT', 'GOOGL', 'AMZN']
predictions = {}
for company in top_companies:
    prediction = get_predictions(company, model, scaler)
    predictions[company] = prediction

# Display predictions
for company, prediction in predictions.items():
    print(f"Predicted closing price for {company}: {prediction[-1]}")
# Out:
# Predicted closing price for AAPL: 116.3813247680664
# Predicted closing price for MSFT: 409.63818359375
# Predicted closing price for GOOGL: 72.87936401367188
# Predicted closing price for AMZN: 81.9839859008789

# %%
# Define a function to get predictions for a given company
def get_predictions(company_name, model, scaler):
    # Filter data for the given company
    company_data = df[df['Company'] == company_name]['Close'].values.reshape(-1, 1)
    company_data = scaler.transform(company_data).reshape(1, -1, 1)

    # Convert to PyTorch tensor and move to device
    company_data = torch.tensor(company_data, dtype=torch.float32).to(device)

    # Get initial hidden state
    batch_size = 1
    h0 = torch.zeros(1, batch_size, hidden_size).to(device)

    # Get predictions
    with torch.no_grad():
        prediction = model(company_data)

    # Inverse transform predictions
    prediction = scaler.inverse_transform(prediction.cpu().numpy()).reshape(-1)

    return prediction

# Get predictions for the top 4 companies
top_companies = ['AAPL', 'MSFT', 'GOOGL', 'AMZN']
predictions = {}
for company in top_companies:
    prediction = get_predictions(company, model, scaler)
    predictions[company] = prediction

# Display predictions
for company, prediction in predictions.items():
    print(f"Predicted closing price for {company}: {prediction[-1]}")
# Out:
# Predicted closing price for AAPL: 143.85731506347656
# Predicted closing price for MSFT: 137.5020294189453
# Predicted closing price for GOOGL: 145.65074157714844
# Predicted closing price for AMZN: 145.32960510253906

# %%
df.reset_index(drop=True, inplace=True)


# Predictions for the top 4 companies
for company in top_companies:
    company_indices = df[df['Company'] == company].index
    company_data = X[company_indices, -seq_length:, :]
    prediction = model(company_data.float()).cpu().detach().numpy()[0][0]
    prediction = scaler.inverse_transform([[prediction]])[0][0]
    print(f"Predicted closing price for {company}: {prediction}")


df.reset_index(drop=True, inplace=True)

# Predictions for all companies
for company in df['Company'].unique():
    company_indices = df[df['Company'] == company].index
    company_data = X[company_indices, -seq_length:, :]
    prediction = model(company_data.float()).cpu().detach().numpy()[0][0]
    prediction = scaler.inverse_transform([[prediction]])[0][0]
    print(f"Predicted closing price for {company}: {prediction}")
# Out:
# Predicted closing price for AAPL: 175.75054527946457
# Predicted closing price for MSFT: 250.74593979432632
# Predicted closing price for GOOGL: 130.7617462710512
# Predicted closing price for AMZN: 153.3140644010212
# Predicted closing price for AAPL: 175.75054527946457
# Predicted closing price for MSFT: 250.74593979432632
# Predicted closing price for GOOGL: 130.7617462710512
# Predicted closing price for AMZN: 153.3140644010212
# Predicted closing price for NVDA: 46.455651989584766
# Predicted closing price for META: 125.76636075189542
# Predicted closing price for TSLA: 132.43455374852647
# Predicted closing price for LLY: 102.86290107572768
# Predicted closing price for V: 125.90473411422971
# Predicted closing price for TSM: 123.40064791337988
# Predicted closing price for UNH: 127.6023384972353
# Predicted closing price for AVGO: 231.31698808063283
# Predicted closing price for NVO: 197.0459877704945
# Predicted closing price for JPM: 95.80656975098965
# Predicted closing price for WMT: 260.3884068249822
# Predicted closing price for XOM: 138.80483098238662
# Predicted closing price for MA: 186.7042855640688
# Predicted closing price for JNJ: 83.89995836810493
# Predicted closing price for PG: 240.8611254212547
# Predicted closing price for ORCL: 107.17444083248665
# Predicted closing price for HD: 10.972081664909751
# Predicted closing price for ADBE: -1.15264971503791
# Predicted closing price for ASML: 74.30550269482727
# Predicted closing price for CVX: 144.2299957077538
# Predicted closing price for COST: 352.5883486081809
# Predicted closing price for TM: 107.83032580822291
# Predicted closing price for MRK: 200.93701355143432
# Predicted closing price for KO: 160.03699367006337
# Predicted closing price for ABBV: 259.761517080337
# Predicted closing price for BAC: 86.24967426239141
# Predicted closing price for PEP: 100.3869295967215
# Predicted closing price for FMX: 39.409106837554475
# Predicted closing price for CRM: 158.3183627672792
# Predicted closing price for SHEL: 150.0033876014644
# Predicted closing price for ACN: 122.18443476617622
# Predicted closing price for NFLX: 118.91376982564856
# Predicted closing price for MCD: 208.81700893915558
# Predicted closing price for AMD: 131.89057862467837
# Predicted closing price for LIN: 193.20381485926725
# Predicted closing price for NVS: 95.94938465647402
# Predicted closing price for AZN: 117.78741377600036
# Predicted closing price for CSCO: 125.19652451728443
# Predicted closing price for TMO: 251.00519127231695
# Predicted closing price for BABA: 91.14072867184092
# Predicted closing price for INTC: 162.9643174732389
# Predicted closing price for PDD: 177.7433203760882
# Predicted closing price for SAP: 63.07215454361766
# Predicted closing price for ABT: 100.17592756252566
# Predicted closing price for TMUS: 115.15015927447455
# Predicted closing price for PFE: 73.8456264664517
# Predicted closing price for DIS: 104.95395249818849
# Predicted closing price for NKE: 49.674884106730914
# Predicted closing price for CMCSA: 88.48991555938656
# Predicted closing price for DHR: 174.99737121553216
# Predicted closing price for INTU: 464.41280957157556
# Predicted closing price for TTE: 96.96555390205035
# Predicted closing price for WFC: 132.5888460612637
# Predicted closing price for VZ: 151.99131066111633
# Predicted closing price for BHP: 168.40321488457084
# Predicted closing price for HDB: 108.9387145432982
# Predicted closing price for HSBC: 119.21843218265731
# Predicted closing price for PM: 46.264460387220936
# Predicted closing price for QCOM: 39.08393826168603
# Predicted closing price for IBM: 171.9688935248298
# Predicted closing price for AMGN: 74.50160790823605
# Predicted closing price for TXN: 138.12458653359874
# Predicted closing price for NOW: 170.87454983586167
# Predicted closing price for BA: 185.62489206008456
# Predicted closing price for COP: 136.985619728912
# Predicted closing price for UNP: 189.15046750643907
# Predicted closing price for BX: 153.35005752553656
# Predicted closing price for SPGI: 185.00234534007222
# Predicted closing price for UPS: 88.78198191347852
# Predicted closing price for GE: 118.98283541113832
# Predicted closing price for MS: 89.4324914726205
# Predicted closing price for HON: 91.58645517818479
# Predicted closing price for CAT: 29.6789911661035
# Predicted closing price for AMAT: 86.12202299867818
# Predicted closing price for BUD: 128.06662548172432
# Predicted closing price for AXP: 105.613997828807
# Predicted closing price for RY: 68.19897607952214
# Predicted closing price for NEE: 150.3372955907954
# Predicted closing price for UL: 90.46780615003777
# Predicted closing price for SNY: 161.10166891807296
# Predicted closing price for RTX: 254.29350949964396
# Predicted closing price for T: 124.70436910724474
# Predicted closing price for LOW: 680.3426414788473
# Predicted closing price for SBUX: 3.6168944182699647
# Predicted closing price for RIO: 144.60163115799654
# Predicted closing price for TD: 78.835462109139
# Predicted closing price for SYK: 154.55200190750026
# Predicted closing price for BLK: 121.49928979083396
# Predicted closing price for LMT: 89.36058526988502
# Predicted closing price for GS: 6.065046730984079
# Predicted closing price for ELV: 81.34535269262672
# Predicted closing price for ISRG: 148.99117449009407
# Predicted closing price for BKNG: 2.0490214764187726
# Predicted closing price for SONY: 22.186698983038255
# Predicted closing price for MDT: 99.22537575433739
# Predicted closing price for PLD: 76.10051418300273
# Predicted closing price for SCHW: 145.6047492656313
# Predicted closing price for DE: 272.70308190607597
# Predicted closing price for MUFG: 150.74042207456478
# Predicted closing price for BP: 99.11865967552743
# Predicted closing price for TJX: 79.01013133518211
# Predicted closing price for BMY: 119.92897030580582
# Predicted closing price for PBR: 99.30200263602163
# Predicted closing price for MMC: 158.17492391118594
# Predicted closing price for MDLZ: 205.52513173039503
# Predicted closing price for AMT: 273.8222604712529
# Predicted closing price for PGR: 164.90388641317156
# Predicted closing price for LRCX: 307.20466070076384
# Predicted closing price for SHOP: 104.10246105903673
# Predicted closing price for ADP: 161.88835775007263
# Predicted closing price for EQNR: 117.49012594049725
# Predicted closing price for GILD: 111.08706474585168
# Predicted closing price for CB: 34.20817474709236
# Predicted closing price for ADI: 35.92678923012366
# Predicted closing price for PANW: 93.38607240703897
# Predicted closing price for VRTX: 230.62055247272656
# Predicted closing price for ETN: 169.4676807807314
# Predicted closing price for UBS: 177.0968049218307
# Predicted closing price for CVS: 67.99827744024928
# Predicted closing price for C: 160.39982505406667
# Predicted closing price for REGN: 230.4889809930167
# Predicted closing price for KKR: 140.33155345797093
# Predicted closing price for MU: 103.54123390609993
# Predicted closing price for SNPS: 211.931844267584
# Predicted closing price for CI: 150.11495776971518
# Predicted closing price for MELI: 185.48937573474882
# Predicted closing price for BSX: 70.99824838750833
# Predicted closing price for ZTS: 98.01033867193269
# Predicted closing price for IBN: 37.59036470155041
# Predicted closing price for DEO: 120.41062323141901
# Predicted closing price for FI: 104.45438562219921
# Predicted closing price for CME: 136.7568894927944
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-074d49941987> in <cell line: 16>()
#      15 # Predictions for all companies
#      16 for company in df['Company'].unique():
# ---> 17     company_indices = df[df['Company'] == company].index
#      18     company_data = X[company_indices, -seq_length:, :]
#      19     prediction = model(company_data.float()).cpu().detach().numpy()[0][0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
#    6095         with np.errstate(all="ignore"):
# -> 6096             res_values = ops.comparison_op(lvalues, rvalues, op)
#    6097
#    6098         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     291
#     292     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     294
#     295     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      80         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81     else:
# ---> 82         result = libops.scalar_compare(x.ravel(), y, op)
#      83     return result.reshape(x.shape)
#      84
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

df.reset_index(drop=True, inplace=True)

# Predictions for the top 4 companies
for company in top_companies:
    company_indices = df[df['Company'] == company].index
    company_data = X[company_indices, -seq_length:, :]
    prediction = model(company_data.float()).cpu().detach().numpy()[0][0]
    prediction = scaler.inverse_transform([[prediction]])[0][0]

    # Calculate RMSE and r-squared
    true_values = df.loc[company_indices[0] + seq_length, 'Close']
    mse = (mean_squared_error([true_values], [prediction]))

    # Print results
    print(f"Company: {company}")
    print(f"Predicted closing price: {prediction}")
    print(f"MSE: {mse}\n")

print("---------------------For all companies------------------------")

# Predictions for all companies
for company in df['Company'].unique():
    company_indices = df[df['Company'] == company].index
    company_data = X[company_indices, -seq_length:, :]
    prediction = model(company_data.float()).cpu().detach().numpy()[0][0]
    prediction = scaler.inverse_transform([[prediction]])[0][0]

    # Calculate RMSE and r-squared
    true_values = df.loc[company_indices[0] + seq_length, 'Close']
    mse = (mean_squared_error([true_values], [prediction]))

    # Print results
    print(f"Company: {company}")
    print(f"Predicted closing price: {prediction}")
    print(f"MSE: {mse}\n")
# Out:
# Company: AAPL
# Predicted closing price: 175.75054527946457
# MSE: 7484.341542777006
#
# Company: MSFT
# Predicted closing price: 250.74593979432632
# MSE: 2720.1915045307655
#
# Company: GOOGL
# Predicted closing price: 130.7617462710512
# MSE: 12361.45833578801
#
# Company: AMZN
# Predicted closing price: 153.3140644010212
# MSE: 3450.645532693223
#
# ---------------------For all companies------------------------
# Company: AAPL
# Predicted closing price: 175.75054527946457
# MSE: 7484.341542777006
#
# Company: MSFT
# Predicted closing price: 250.74593979432632
# MSE: 2720.1915045307655
#
# Company: GOOGL
# Predicted closing price: 130.7617462710512
# MSE: 12361.45833578801
#
# Company: AMZN
# Predicted closing price: 153.3140644010212
# MSE: 3450.645532693223
#
# Company: NVDA
# Predicted closing price: 46.455651989584766
# MSE: 1842.087461007709
#
# Company: META
# Predicted closing price: 125.76636075189542
# MSE: 4166.502887969588
#
# Company: TSLA
# Predicted closing price: 132.43455374852647
# MSE: 3462.646328289613
#
# Company: LLY
# Predicted closing price: 102.86290107572768
# MSE: 601.4898568150052
#
# Company: V
# Predicted closing price: 125.90473411422971
# MSE: 1946.5371509178283
#
# Company: TSM
# Predicted closing price: 123.40064791337988
# MSE: 6283.450812595713
#
# Company: UNH
# Predicted closing price: 127.6023384972353
# MSE: 826.2941699451195
#
# Company: AVGO
# Predicted closing price: 231.31698808063283
# MSE: 315.87982251256705
#
# Company: NVO
# Predicted closing price: 197.0459877704945
# MSE: 1183.0371593430766
#
# Company: JPM
# Predicted closing price: 95.80656975098965
# MSE: 0.17878221938334443
#
# Company: WMT
# Predicted closing price: 260.3884068249822
# MSE: 1946.6502180957689
#
# Company: XOM
# Predicted closing price: 138.80483098238662
# MSE: 289.8449115433572
#
# Company: MA
# Predicted closing price: 186.7042855640688
# MSE: 15103.812378882847
#
# Company: JNJ
# Predicted closing price: 83.89995836810493
# MSE: 1735.9912743951902
#
# Company: PG
# Predicted closing price: 240.8611254212547
# MSE: 28790.016846047798
#
# Company: ORCL
# Predicted closing price: 107.17444083248665
# MSE: 6771.406067814439
#
# Company: HD
# Predicted closing price: 10.972081664909751
# MSE: 8402.300790416559
#
# Company: ADBE
# Predicted closing price: -1.15264971503791
# MSE: 6426.10946484155
#
# Company: ASML
# Predicted closing price: 74.30550269482727
# MSE: 4279.0566173918
#
# Company: CVX
# Predicted closing price: 144.2299957077538
# MSE: 9106.31633823723
#
# Company: COST
# Predicted closing price: 352.5883486081809
# MSE: 40972.49056060031
#
# Company: TM
# Predicted closing price: 107.83032580822291
# MSE: 32731.928509658774
#
# Company: MRK
# Predicted closing price: 200.93701355143432
# MSE: 1048.3699737404288
#
# Company: KO
# Predicted closing price: 160.03699367006337
# MSE: 19211.898609653985
#
# Company: ABBV
# Predicted closing price: 259.761517080337
# MSE: 12751.714396442916
#
# Company: BAC
# Predicted closing price: 86.24967426239141
# MSE: 353.73401333630864
#
# Company: PEP
# Predicted closing price: 100.3869295967215
# MSE: 4247.2814407973365
#
# Company: FMX
# Predicted closing price: 39.409106837554475
# MSE: 1.6119720620143527
#
# Company: CRM
# Predicted closing price: 158.3183627672792
# MSE: 7621.074143123257
#
# Company: SHEL
# Predicted closing price: 150.0033876014644
# MSE: 39.395847877693036
#
# Company: ACN
# Predicted closing price: 122.18443476617622
# MSE: 6493.620820633074
#
# Company: NFLX
# Predicted closing price: 118.91376982564856
# MSE: 9307.188161327118
#
# Company: MCD
# Predicted closing price: 208.81700893915558
# MSE: 12936.264715889227
#
# Company: AMD
# Predicted closing price: 131.89057862467837
# MSE: 4163.465898891642
#
# Company: LIN
# Predicted closing price: 193.20381485926725
# MSE: 15506.18039110176
#
# Company: NVS
# Predicted closing price: 95.94938465647402
# MSE: 3634.3702011980254
#
# Company: AZN
# Predicted closing price: 117.78741377600036
# MSE: 12.055044361563692
#
# Company: CSCO
# Predicted closing price: 125.19652451728443
# MSE: 2973.2618860851117
#
# Company: TMO
# Predicted closing price: 251.00519127231695
# MSE: 46606.01109271279
#
# Company: BABA
# Predicted closing price: 91.14072867184092
# MSE: 5.452306645655444
#
# Company: INTC
# Predicted closing price: 162.9643174732389
# MSE: 1534.7986138290546
#
# Company: PDD
# Predicted closing price: 177.7433203760882
# MSE: 18961.56438474628
#
# Company: SAP
# Predicted closing price: 63.07215454361766
# MSE: 268.6036804329326
#
# Company: ABT
# Predicted closing price: 100.17592756252566
# MSE: 2916.422036504561
#
# Company: TMUS
# Predicted closing price: 115.15015927447455
# MSE: 6967.977836734338
#
# Company: PFE
# Predicted closing price: 73.8456264664517
# MSE: 604.6922910937355
#
# Company: DIS
# Predicted closing price: 104.95395249818849
# MSE: 5095.556527484606
#
# Company: NKE
# Predicted closing price: 49.674884106730914
# MSE: 255.1558704322051
#
# Company: CMCSA
# Predicted closing price: 88.48991555938656
# MSE: 1411.4373533464284
#
# Company: DHR
# Predicted closing price: 174.99737121553216
# MSE: 7055.712175738392
#
# Company: INTU
# Predicted closing price: 464.41280957157556
# MSE: 84523.23737890579
#
# Company: TTE
# Predicted closing price: 96.96555390205035
# MSE: 147.69097053461334
#
# Company: WFC
# Predicted closing price: 132.5888460612637
# MSE: 2163.288008476007
#
# Company: VZ
# Predicted closing price: 151.99131066111633
# MSE: 32715.10028853304
#
# Company: BHP
# Predicted closing price: 168.40321488457084
# MSE: 12665.769007230985
#
# Company: HDB
# Predicted closing price: 108.9387145432982
# MSE: 711.6090311058832
#
# Company: HSBC
# Predicted closing price: 119.21843218265731
# MSE: 8364.696410685146
#
# Company: PM
# Predicted closing price: 46.264460387220936
# MSE: 15930.83898708823
#
# Company: QCOM
# Predicted closing price: 39.08393826168603
# MSE: 3297.568801729192
#
# Company: IBM
# Predicted closing price: 171.9688935248298
# MSE: 15686.768062561032
#
# Company: AMGN
# Predicted closing price: 74.50160790823605
# MSE: 1322.1371680144673
#
# Company: TXN
# Predicted closing price: 138.12458653359874
# MSE: 43.26769418142031
#
# Company: NOW
# Predicted closing price: 170.87454983586167
# MSE: 3089.044159808176
#
# Company: BA
# Predicted closing price: 185.62489206008456
# MSE: 22835.0873867799
#
# Company: COP
# Predicted closing price: 136.985619728912
# MSE: 4170.1451838610665
#
# Company: UNP
# Predicted closing price: 189.15046750643907
# MSE: 7312.312860410193
#
# Company: BX
# Predicted closing price: 153.35005752553656
# MSE: 8556.5897929366
#
# Company: SPGI
# Predicted closing price: 185.00234534007222
# MSE: 21153.87599941347
#
# Company: UPS
# Predicted closing price: 88.78198191347852
# MSE: 1843.0762645278905
#
# Company: GE
# Predicted closing price: 118.98283541113832
# MSE: 6678.817881079539
#
# Company: MS
# Predicted closing price: 89.4324914726205
# MSE: 485.1133025981231
#
# Company: HON
# Predicted closing price: 91.58645517818479
# MSE: 5795.327196345682
#
# Company: CAT
# Predicted closing price: 29.6789911661035
# MSE: 3075.4266940150023
#
# Company: AMAT
# Predicted closing price: 86.12202299867818
# MSE: 654.6557355885953
#
# Company: BUD
# Predicted closing price: 128.06662548172432
# MSE: 9730.681433926084
#
# Company: AXP
# Predicted closing price: 105.613997828807
# MSE: 3716.2493174108886
#
# Company: RY
# Predicted closing price: 68.19897607952214
# MSE: 8706.425052127912
#
# Company: NEE
# Predicted closing price: 150.3372955907954
# MSE: 48483.89921666638
#
# Company: UL
# Predicted closing price: 90.46780615003777
# MSE: 30328.82548116854
#
# Company: SNY
# Predicted closing price: 161.10166891807296
# MSE: 177.8012536714747
#
# Company: RTX
# Predicted closing price: 254.29350949964396
# MSE: 438.6834636745124
#
# Company: T
# Predicted closing price: 124.70436910724474
# MSE: 2396.326978215198
#
# Company: LOW
# Predicted closing price: 680.3426414788473
# MSE: 1403768.5346577878
#
# Company: SBUX
# Predicted closing price: 3.6168944182699647
# MSE: 2329.3274634943355
#
# Company: RIO
# Predicted closing price: 144.60163115799654
# MSE: 3536.9759686253774
#
# Company: TD
# Predicted closing price: 78.835462109139
# MSE: 385.4830334572383
#
# Company: SYK
# Predicted closing price: 154.55200190750026
# MSE: 12879.027176404741
#
# Company: BLK
# Predicted closing price: 121.49928979083396
# MSE: 317.89892308539396
#
# Company: LMT
# Predicted closing price: 89.36058526988502
# MSE: 7034.275111905961
#
# Company: GS
# Predicted closing price: 6.065046730984079
# MSE: 607.7818556342673
#
# Company: ELV
# Predicted closing price: 81.34535269262672
# MSE: 1368.3237609097437
#
# Company: ISRG
# Predicted closing price: 148.99117449009407
# MSE: 10999.151648857342
#
# Company: BKNG
# Predicted closing price: 2.0490214764187726
# MSE: 12.563467569439728
#
# Company: SONY
# Predicted closing price: 22.186698983038255
# MSE: 3401.007005708366
#
# Company: MDT
# Predicted closing price: 99.22537575433739
# MSE: 3527.505932760035
#
# Company: PLD
# Predicted closing price: 76.10051418300273
# MSE: 4793.653713180232
#
# Company: SCHW
# Predicted closing price: 145.6047492656313
# MSE: 8000.37002258229
#
# Company: DE
# Predicted closing price: 272.70308190607597
# MSE: 17234.226448020407
#
# Company: MUFG
# Predicted closing price: 150.74042207456478
# MSE: 18451.533485329433
#
# Company: BP
# Predicted closing price: 99.11865967552743
# MSE: 1043.479975688532
#
# Company: TJX
# Predicted closing price: 79.01013133518211
# MSE: 3768.116552465927
#
# Company: BMY
# Predicted closing price: 119.92897030580582
# MSE: 3961.7027322613517
#
# Company: PBR
# Predicted closing price: 99.30200263602163
# MSE: 500.26817952804595
#
# Company: MMC
# Predicted closing price: 158.17492391118594
# MSE: 5833.770683188503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-653c26f0fdca> in <cell line: 25>()
#      24 # Predictions for all companies
#      25 for company in df['Company'].unique():
# ---> 26     company_indices = df[df['Company'] == company].index
#      27     company_data = X[company_indices, -seq_length:, :]
#      28     prediction = model(company_data.float()).cpu().detach().numpy()[0][0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
#    6095         with np.errstate(all="ignore"):
# -> 6096             res_values = ops.comparison_op(lvalues, rvalues, op)
#    6097
#    6098         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     291
#     292     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     294
#     295     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      80         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81     else:
# ---> 82         result = libops.scalar_compare(x.ravel(), y, op)
#      83     return result.reshape(x.shape)
#      84
#
# KeyboardInterrupt:

# %%
df["Company"]
# Out:
# Date_ints
# 1514764800     AAPL
# 1514764800     MSFT
# 1514764800    GOOGL
# 1514764800     AMZN
# 1514764800     AAPL
#               ...
# 1672531200     AMZN
# 1672531200     AAPL
# 1672531200     MSFT
# 1672531200    GOOGL
# 1672531200     AMZN
# Name: Company, Length: 5032, dtype: object

# %%
unique_companies = df["Company"].apply(lambda x: x).unique()

unique_companies
# Out:
# array(['AAPL', 'MSFT', 'GOOGL', 'AMZN'], dtype=object)
